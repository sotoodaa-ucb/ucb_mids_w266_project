# %% [markdown]
# ## Kaggle
#
# Unfortunately, the competition is closed at time of writing, meaning we cannot accept the rules and download the data.

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-0d02ced6-19ec-4e3f-94e2-4ab5954a5465" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0d02ced6-19ec-4e3f-94e2-4ab5954a5465">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !mkdir ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# Out:
# mkdir: cannot create directory ‘/root/.kaggle’: File exists

# %%
# !kaggle competitions download -c AI4Code
# Out:
# ...
# 403 - Forbidden

# %%
# !kaggle kernels output robikscube/google-ai4code-data-to-parquet-twitch-stream-eda -p .
# Out:
# ...
# Kernel log downloaded to ./google-ai4code-data-to-parquet-twitch-stream-eda.log

# %% [markdown]
# ## Google Drive
#
# As an alternative, this kind person uploaded a duplicate of the dataset (as parquet, a more compressed format), so I downloaded it locally, and uploaded it to our shared Google Drive Folder [here](https://drive.google.com/drive/folders/1je1t9g5DLCLqvb5TGfqDwvnmV5nMfKv5).

# %%
# 1. Go to https://drive.google.com/drive/shared-with-me
# 2. Right Click W266 NLP Project -> Add Shortcut To Drive -> My Drive -> Add Shortcut
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import pandas as pd
all = pd.read_parquet('/content/gdrive/MyDrive/W266 NLP Project/Data/train_all.parquet')
orders = pd.read_parquet('/content/gdrive/MyDrive/W266 NLP Project/Data/train_orders.parquet')
ancestors = pd.read_parquet('/content/gdrive/MyDrive/W266 NLP Project/Data/train_ancestors.parquet')

# %%
all.head()
# Out:
#                id      cell cell_type  \
# 0  00001756c60be8  1862f0a6      code
# 1  00001756c60be8  448eb224  markdown
# 2  00001756c60be8  2a9e43d6      code
# 3  00001756c60be8  7e2f170a  markdown
# 4  00001756c60be8  038b763d      code
#
#                                               source  order ancestor_id  \
# 0  # This Python 3 environment comes with many he...      0    945aea18
# 1  **Импортируем необходимые для работы функции и...      1    945aea18
# 2  import numpy as np\nimport pandas as pd\nimpor...      2    945aea18
# 3                      **Подключаем предупреждения**      3    945aea18
# 4  import warnings\nwarnings.filterwarnings('igno...      4    945aea18
#
#   parent_id
# 0      None
# 1      None
# 2      None
# 3      None
# 4      None

# %%
orders.head()
# Out:
#                id                                         cell_order
# 0  00001756c60be8  1862f0a6 448eb224 2a9e43d6 7e2f170a 038b763d 7...
# 1  00015c83e2717b  2e94bd7a 3e99dee9 b5e286ea da4f7550 c417225b 5...
# 2  0001bdd4021779  3fdc37be 073782ca 8ea7263c 80543cd8 38310c80 0...
# 3  0001daf4c2c76d  97266564 a898e555 86605076 76cc2642 ef279279 d...
# 4  0002115f48f982  9ec225f0 18281c6c e3b6b115 4a044c54 365fe576 a...

# %%
ancestors.head()
# Out:
#                id ancestor_id       parent_id
# 0  00001756c60be8    945aea18            None
# 1  00015c83e2717b    aa2da37e  317b65d12af9df
# 2  0001bdd4021779    a7711fde            None
# 3  0001daf4c2c76d    090152ca            None
# 4  0002115f48f982    272b483a            None
